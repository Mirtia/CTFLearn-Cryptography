# %% [markdown]
# # Encyrption Master

# %%
import base64
import binascii

output_0 = base64.b64decode(b"...")
input_1 = "..."
output_1 = binascii.unhexlify(input_1)
input_2 = int("...", 2)
output_2 = binascii.unhexlify("%x" % input_2)
input_3 = b"Q1RGe0lfQU1fUFJPVURfT0ZfWU9VfQ=="
output_3 = base64.b64decode(input_3)
output_3
